# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
WorldCup = pd.read_csv("")
Club = pd.read_csv("")

# %%
WorldCupPlayers=list(WorldCup['Player'])

# %%
ClubPlayers=list(Club['Player'])

# %%
InBoth = []
for element in ClubPlayers:
    if element in WorldCupPlayers:
        InBoth.append(element)

# %%
CupData = WorldCup['Player'].isin(InBoth)
ClubData = Club['Player'].isin(InBoth)

# %%
Poppers = WorldCup[CupData]

# %%
CupX=list(Poppers['xG p90'])

# %%
Doppers = Club[ClubData]

# %%
ClubX=list(Doppers['xG p90'])

# %%
Poppers.head(60)
# Out:
#       Rk               Player   Pos              Squad     Age    Born  MP  \
# 0      1     Brenden Aaronson    MF   us United States  22-034  2000.0   1
# 9     10          Tyler Adams    MF   us United States  23-284  1999.0   1
# 12    13         Nayef Aguerd    DF         ma Morocco  26-240  1996.0   1
# 14    15        Manuel Akanji    DF     ch Switzerland  27-129  1995.0   1
# 15    16           Nathan Aké    DF     nl Netherlands  27-280  1995.0   1
# 19    20              Alisson    GK          br Brazil  30-054  1992.0   1
# 22    23       Julián Álvarez    MF       ar Argentina  22-298  2000.0   1
# 24    25       Daniel Amartey    DF           gh Ghana  27-339  1994.0   1
# 28    29     Joachim Andersen    DF         dk Denmark  26-178  1996.0   1
# 30    31               Antony    FW          br Brazil  22-274  2000.0   1
# 38    39          Jordan Ayew    FW           gh Ghana  31-075  1991.0   1
# ...

# %%
Doppers.head(60)
# Out:
#       Rk              Player   Nation   Pos     Age  Born  MP  Starts   Min  \
# 0      1    Brenden Aaronson   us USA  MFFW  22-034  2000  14      14  1189
# 2      3         Tyler Adams   us USA    MF  23-284  1999  13      13  1166
# 4      5        Nayef Aguerd   ma MAR    DF  26-240  1996   1       0    76
# 7      8       Manuel Akanji   ch SUI    DF  27-129  1995   8       8   701
# 8      9          Nathan Aké   nl NED    DF  27-280  1995   8       7   571
# 12    13             Alisson   br BRA    GK  30-054  1992  14      14  1260
# 15    16      Julián Álvarez   ar ARG  FWMF  22-298  2000  12       3   364
# 16    17      Daniel Amartey   gh GHA    DF  27-339  1994  12      10   915
# 17    18    Joachim Andersen   dk DEN    DF  26-178  1996  13      13  1170
# 21    22              Antony   br BRA  FWMF  22-274  2000   6       6   491
# 32    33         Jordan Ayew   gh GHA  FWMF  31-075  1991  14      11   904
# ...

# %%
#Dendoncker Duplicated
